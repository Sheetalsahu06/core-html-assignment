# %% [markdown]
# **1. Build a simple webpage that displays text as shown in the below image.**
# ![{500416F6-53E3-45DB-A1FD-3842C91DDC65}.png](data:image/png;base64,...)
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Formatting tags</title>
#   </head>
#
#   <body>
#     <div>
#       <p><b>This text will be bolded.</b></p>
#       <p><i>This will be italic.</i></p>
#       <p><ins>This text will be underline</ins></p>
#       <p><mark>This will be highlighted</mark></p>
#       <p>
#         This is normal text <sup>This will be super scripted</sup>This is normal
#         again
#       </p>
#       <p>This is normal text <sub>This will be subscripted</sub></p>
#       <p>Normal Text <small>Small Text</small></p>
#       <p><del>This text will be deleted</del></p>
#     </div>
#   </body>
# </html>
#
# ```
#
# **Output:**
#
# ![{C31D8BD5-0C2F-465E-974E-16A453D596A6}.png](data:image/png;base64,...)
#
# **2. Build a simple webpage that helps users navigate different web development-related websites. Note: On clicking the hyperlink the web pages should open in a new tab. Below is a reference image.**
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Hyperlink</title>
# </head>
# <body>
#     <div>
#         <h1>Nevigate me:</h1>
#         <p>Take me to <a href="https://pwskills.com/" target="_blank">PW Skills </a>to buy a course</p>
#         <p>Take me to <a href="https://developer.mozilla.org/en-US/" target="_blank">MDN Docs </a>to know more about Web Development</p>
#         <p>Take me to <a href="https://code.visualstudio.com/" target="_blank">Vs code</a> to download vs code for windows 11</p>
#     </div>
# </body>
# </html>
# ```
# **Output:**
#
# ![{8D88E2AF-740D-4CBD-87B9-3FC96D5172A4}.png](data:image/png;base64,...)
#
# **3.Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information. For the home page you can add some information about yourself.**
#
# a. `Home.html`
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Home page</title>
#   </head>
#   <body>
#     <h1>Home</h1>
#     <p>
#       Hello Everyone,This is my first blog web page and i am from
#       durg,Chhattisgarh and i am a student of Btech cse 2nd year and currently i am
#       learning Full stack Web Development from pwskills
#     </p>
#     <h2> Web Development</h2>
#     <a href="web dev.html" target="_blank">
#       Click on it to learn about</a
#     >
#     <h2>
#         Web Design
#     </h2>
#     <a href="Web-design.html" target="_blank"> Click on it to learn about</a>
#
#   </body>
# </html>
#
# ```
# **Output:**
#
# ![{A354FC60-832B-4955-B621-E17A4B0D003B}.png](data:image/png;base64,...)
#
# b. `web dev.html`
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>web Development</title>
# </head>
# <body>
#     <h1>Web Development</h1>
#     <p>Web development is the process of creating and maintaining websites and web applications. It involves designing the structure, layout, and functionality of a website, and writing code to make it work. </p>
#         <h3>Types of web development</h3>
#         <h4>Front-end development</h4>
#         <p>The part of a website that users see and interact with. Front-end developers design the look and feel of a website, and ensure it works well on any device. They use programming languages like HTML, CSS, and JavaScript.</p>
#         <h4>  Back-end development</h4>
#         <p>The part of a website that happens on the server side, and is not visible to the user. Back-end developers focus on the databases, logic, and architecture of a website. </p>
#         <h4>   Full-stack development</h4>
#         <p>The process of designing, building, and maintaining the entire website, including both the front-end and back-end. Full-stack developers have expertise in both front-end and back-end technologies.</p>
#        <h4> Web development life cycle</h4>
#        <ul>
#         <li>Gathering information</li>
#         <li>Planning</li>
#         <li> Design and layout</li>
#         <li>Content creation</li>
#         <li>Development</li>
#         <li>Testing, review, and launch</li>
#         <li>Maintenance and updates</li>
#        </ul>
# </body>
# </html>
# ```
# **Output:**
#
# ![{6513F744-BFFE-46B2-9247-89CFA09FB501}.png](data:image/png;base64,...)
#
# c. `Web-design.html`
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web Design</title>
# </head>
# <body>
#     <h1>Web Design</h1>
#     <p>Web design is the process of planning and arranging content on a website to make it accessible online. It is a type of digital design that involves the look and feel of a website, including its colors, fonts, graphics, and user interface. </p>
#     <h2>What does web design include? </h2>
#     <ul>
#         <li><b>Color scheme:</b> The colors used on the website</li>
#         <li><b>Graphic design:</b> The images and illustrations used on the website</li>
#         <li><b>User interface (UI) design: </b> The design of the website's navigation and interactions</li>
#         <li><b>Layout:</b> The arrangement of content on the website</li>
#         <li><b>Information flow: </b> How information is presented on the website</li>
#     </ul>
#     <h2>Why is web design important?</h2>
#     <ul>
#         <li>A good web design can help a website rank higher in search engines </li>
#         <li>A good web design can improve a website's visibility to its audience </li>
#         <li>A good web design can increase the amount of time visitors spend on a website </li>
#     </ul>
#     <h2>Tools used in web design</h2>
#     <h3>Figma</h3>
#     <p>A tool for creating, sharing, and testing designs for websites, mobile apps, and other digital products </p>
#     <h3>Google Web Designer</h3>
#     <p>A tool for creating HTML5 content with animation and interactive elements </p>
#     <h3>Adobe Dreamweaver</h3>
#     <p>A web design software that supports HTML, CSS, JavaScript, and more </p>
#
# </body>
# </html>
# ```
# **Output:**
#
# ![{AF3BB2F4-634D-49B5-BCE9-D6310AFBA1FC}.png](data:image/png;base64,...)
#
#
#
# **4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag.**
# ```
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
# </head>
#
# <body>
#     <h1>Lists of HTML Tags</h1>
#     <ol>
#         <li>html tag - The root element that encloses all HTML content</li>
#         <li>
#             head tag - Contains meta-information, such as the title, links to
#             stylesheets, and scripts
#         </li>
#         <li>
#             title tag - Specifies the title of the webpage, displayed in the browser
#             tab.
#         </li>
#         <li>
#             meta tag - Provides metadata such as character set, viewport settings,
#             and seo-realted information
#         </li>
#         <li>
#             link tag - Connects external resources like stylesheets to the document.
#         </li>
#         <li>
#             style tag - Allows for internal CSS styling within an HTML document.
#         </li>
#         <li>body tag - Contains the main content of the webpage.</li>
#         <li>header tag - Defines a section for introductory content or navigation.</li>
#         <li>nav tag- specifies a navigation section with links.</li>
#         <li>main tag - Represents the main content of the document, distinct from headers, sidebars, and footers.</li>
#         <li>section tag - Defines a thematic grouping of content.</li>
#         <li>article tag - Represents a self-contained piece of content, such as a blog post.</li>
#         <li> aside tag - Contains content related to the main content, like sidebars. </li>
#         <li>footer tag - Defines a footer section for copyright, links, and other information. </li>
#         <li>h1 to h6 tag - Headings ranging from most important (h1) to least (h6).</li>
#         <li> p tag - Represents a paragraph of text.</li>
#         <li>br tag - Inserts a line break.</li>
#         <li> hr tag - Adds a horizontal line, often used to separate content.</li>
#         <li>a tag - Creates a hyperlinks to other pages or resources.</li>
#         <li>img tag - Displays images using the src attributes for the image path</li>
#         <li>ul tag - Defines an unordered list. </li>
#         <li>ol tag - Defines aan ordered(numbered)list.</li>
#         <li>li tag -
#             Represents a list item within ul and ol .
#         </li>
#         <li>
#             table tag - Definesa table for displaying tabular data
#         </li>
#         <li>tr tag - Represents a row within a table.</li>
#         <li>th tag - Defines a header cell in a table.</li>
#         <li>td tag - Represents a standard data cell in a table.</li>
#         <li>form tag - Creates an input form for user interaction.</li>
#         <li> input tag - Defines an input field within a form.</li>
#          <li>label tag - Associates a text label with a form control.</li>
#         <li> button tag - Represents a clickable button.</li>
#
#         <li> div tag - A generic container for styling or grouping elements.</li>
#         <li> span tag - A small inline container used for styling or scripting.</li>
#
#     </ol>
# </body>
#
# </html>
# ```
# **Output:**
#
# ![{CFB4E076-20C4-41E7-9A0D-20C7639D5E58}.png](data:image/png;base64,...)
#
#
# **5. Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for.**
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <dl>
#         <dt>HTML</dt>
#         <dd>The standard markup language used to create the structure of web pages.</dd>
#
#         <dt>CSS</dt>
#         <dd>A stylesheet language used to style and layout web pages.</dd>
#
#         <dt>JavaScript</dt>
#         <dd>A programming language that enables interactive and dynamic content on web pages.</dd>
#
#         <dt>React.js</dt>
#         <dd>A JavaScript library for building user interfaces, especially single-page applications.</dd>
#
#         <dt>Node.js</dt>
#         <dd>A runtime environment that allows JavaScript to be executed on the server-side.</dd>
#
#         <dt>Express.js</dt>
#         <dd>A lightweight web application framework for Node.js used to build APIs and web applications.</dd>
#
#         <dt>MongoDB</dt>
#         <dd>A NoSQL database that stores data in JSON-like documents for flexible and scalable storage.</dd>
#
#         <dt>MySQL</dt>
#         <dd>A widely-used relational database management system (RDBMS) that uses SQL for data management.</dd>
#
#     </dl>
#
# </body>
# </html>
# ```
#
# **Output:**
#
# ![{C5BFB2B2-8373-42E4-A372-BE6B2DF7FBFA}.png](data:image/png;base64,...)
#
# **6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech stack, create a table that lists the tech stack name, its primary use cases, and some key features or benefits.**
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#   </head>
#   <body>
#     <div>
#       <ol>
#         <li>HTML</li>
#         <br />
#         <table border="1px">
#           <tr>
#             <th>Primary Use Cases</th>
#             <th>Key Features/Benefits</th>
#           </tr>
#           <tr>
#             <td>Building the structure of web pages</td>
#             <td>
#               <ul>
#                 <li>Simple and easy to learn</li>
#                 <li>Compatible with all web browsers</li>
#                 <li>Allows for semantic markup</li>
#               </ul>
#             </td>
#           </tr>
#         </table>
#         <br />
#         <li>CSS</li>
#         <br />
#         <table border="1px">
#           <tr>
#             <th>Primary Use Cases</th>
#             <th>Key Features/Benefits</th>
#           </tr>
#           <tr>
#             <td>Styling and Layout of Webpages</td>
#             <td>
#               <ul>
#                 <li>Allows for separation of content and presenation</li>
#                 <li>Enables reponsive design</li>
#                 <li>Offers a wide range of Styling options</li>
#               </ul>
#             </td>
#           </tr>
#         </table>
#         <br />
#         <li>JS</li>
#         <br />
#         <table border="1px">
#           <tr>
#             <th>Primary Use Cases</th>
#             <th>Key Features/Benefits</th>
#           </tr>
#           <tr>
#             <td>Add interactivity and dynamic content to web pages</td>
#             <td>
#                 <ul>
#                     <li>make web pages dynamic and interactive. </li>
#                     <li>runs on the user’s browser, so has a faster response time without needing to communicate with the server.</li>
#                     <li> can be used for a wide range of tasks, from simple calculations to complex server-side applications.</li>
#                 </ul>
#             </td>
#           </tr>
#         </table>
#       </ol>
#     </div>
#   </body>
# </html>
# ```
# **Output:**
#
# ![{3B9293B4-E7FB-4F64-8EF2-B6F40018627F}.png](data:image/png;base64,...)
#
# **7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists `(<ul>)` and list items `(<li>)` with inline-block styling to create a structured layout. Apply formatting tags to enhance the presentation of list items.**
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Nested List structure</title>
#   </head>
#   <body>
#     <div>
#       <h1>Table of Contents</h1>
#       <ul style="color: dodgerblue;">
#         <ins>
#           <li>Part 1: Introduction</li>
#           <li>Part 2: Getting Started</li>
#           <ul>
#             <li>2.1 Installing the Software</li>
#             <li>2.2 Creating a New Project</li>
#             <ul>
#               <li>2.2.1 Project Templates</li>
#               <li>2.2.2 Customizing Settings</li>
#             </ul>
#             <li>2.3 Exploring the Interface</li>
#             <ul>
#               <li>2.3.1 Toolbar Features</li>
#               <li>2.3.1 Panel Layout</li>
#               <ul>
#                 <li>2.3.2.1 Docking Panels</li>
#                 <li>2.3.2.2 Tabbed Interface</li>
#               </ul>
#             </ul>
#           </ul>
#           <li>Part 3: Advanced Topics</li>
#           <ul>
#             <li>3.1 Working with Plugins</li>
#             <ul>
#                 <li>3.1.1 Installing Plugins</li>
#                 <li>3.1.2 Plugin Configuration</li>
#             </ul>
#             <li>3.2 Customizing with UI</li>
#             <ul>
#                 <li>3.2.1 Changing Themes</li>
#                 <li>3.2.2 Configuring Shortcuts</li>
#             </ul>
#             <li>3.3 Optimizing Performance</li>
#             <ul>
#                 <li>3.3.1 Caching Strategies</li>
#                 <li>3.3.2 Resource Minification</li>
#             </ul>
#           </ul>
#           <li>Part 4: Conclusion</li>
#         </ins>
#       </ul>
#     </div>
#   </body>
# </html>
#
# ```
# **Output:**
#
# ![{5DC113DE-8983-41C8-8C0D-6CB539D2F7B7}.png](data:image/png;base64,...)
#
# **8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column corresponds to a room. Some time slots might have multiple sessions running simultaneously in different rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule. (use table attribute “cellpadding” to give extra padding in each table cell ).**
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Conference Schedule</title>
# </head>
# <body>
#     <div>
#         <h1>Conference Schedule</h1>
#         <table border="1px" cellpadding="10">
#             <tr >
#                 <th>Time</th>
#                 <th>Room 1</th>
#                 <th>Room 2</th>
#                 <th>Room 3</th>
#                 <th>Room 4</th>
#             </tr>
#             <tr>
#                 <td rowspan="3">9:00 AM - 10:00 AM</td>
#                 <td rowspan="2">Keynote</td>
#                 <td>Session A</td>
#                 <td>Session B</td>
#                 <td rowspan="3">Session C</td>
#             </tr>
#             <tr>
#                 <td>Session D</td>
#                 <td>Session E</td>
#             </tr>
#             <tr>
#                 <td>10:30 AM - 11:30 AM</td>
#                 <td colspan="2">Session F</td>
#             </tr>
#             <tr>
#                 <td>12:00 PM - 1:00 PM</td>
#                 <td colspan="4">Lunch Break</td>
#             </tr>
#             <tr>
#                 <td rowspan="2
#                 ">1:00 - 2:00 PM</td>
#                 <td>Session G</td>
#                 <td rowspan="2">Session H</td>
#                 <td>Session I</td>
#                 <td>Session J</td>
#             </tr>
#             <tr>
#                 <td>Session K</td>
#                 <td>Session L</td>
#                 <td>Session M</td>
#             </tr>
#         </table>
#     </div>
# </body>
# </html>
# ```
# **Output:**
#
# ![{897DADBF-3ACC-4C0C-9431-E866BF3F6AF9}.png](data:image/png;base64,...)
